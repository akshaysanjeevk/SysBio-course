# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from fns import *

plt.rcParams['text.usetex'] = True

# %%
# %run fns.py
fig2a = {
    'header':'xCoherent Type 1 AND($S_Y=1$)',
    'gate':'AND',
    'regXY':'act', 
    'regXZ':'act',
    'regYZ':'act',
    'H':2,
    'Kxz': 0.1,
    'Kyz': None,  # Fixed from None
    'Kxy': 0.1,
    'By': 0, 
    'Bz': 0, 
    'bt_y': 1, 
    'bt_z': 1, 
    'alp_y': 1, 
    'alp_z': 1,
    'tmin': 0,
    'tmax': 10,
    'N': 1000,
    'start': 1,
    'width':6,
    'ystart':0,
    'ywidth':10,
    'Q0': [1, 0]
}
fig2b = {
    'header':'xCoherent Type 4 AND($S_Y=1$)',
    'gate': 'AND',
    'regXY':'rep', 
    'regXZ':'act',
    'regYZ':'rep',
    'H': 2,
    'Kxy': 0.1,
    'Kxz': 0.1,
    'Kyz': .3,
    'By':0,  
    'Bz': 0, 
    'bt_y': 1, 
    'bt_z': 1, 
    'alp_y': 1, 
    'alp_z': 1,
    'tmin': 0,
    'tmax': 10,
    'N': 1000,
    'start': 1,
    'width': 5,
    'ystart':0,
    'ywidth':10,
    'Q0': [1, 0]
}

fig2, ax2= plt.subplots(1,2, figsize=(8,4))
kyz2a = [.5, 5]
for i in kyz2a:
    fig2a['Kyz'] = i
    SolveAndPlot(fig2a, ax2[0])
kyz2b = [.6, .3]
for j in kyz2b:
    fig2b['Kyz'] = j
    SolveAndPlot(fig2b, ax2[1])

# %%
# %run fns.py
fig3a = {
    'header':'Incoherent Type 1 AND($S_Y=1$)',
    'gate':'AND',
    'regXY':'act', 
    'regXZ':'act',
    'regYZ':'rep',
    'H':2,
    'Kxz':.1,
    'Kyz':None,  #[.01, .1, .3],
    'Kxy':.1,
    'By':0, 
    'Bz':0, 
    'bt_y': 1, 
    'bt_z': 1, 
    'alp_y': 1, 
    'alp_z': 1,
    'tmin': 0,
    'tmax': 10,
    'N': 1000,
    'start': 1,
    'width': 5,
    'ystart':1,
    'ywidth':10,
    'Q0': [1, 0]
}
fig3b = {
    'header':'Incoherent Type 4 AND($S_Y=1$)',
    'gate':'AND',
    'regXY':'rep', 
    'regXZ':'act',
    'regYZ':'act',
    'H':2,
    'Kxz':.1,
    'Kyz':None,  #[1,.3,.1],
    'Kxy':.1,
    'By':0, 
    'Bz':0, 
    'bt_y': 1, 
    'bt_z': 1, 
    'alp_y': 1, 
    'alp_z': 1,
    'tmin': 0,
    'tmax': 10,
    'N': 1000,
    'start': 1,
    'width': 5,
    'ystart':0,
    'ywidth':10,
    'Q0': [1, 0]
}
fig3c = {
    'header':'Incoherent Type 1 AND($S_Y=0$)',
    'gate':'AND',
    'regXY':'act', 
    'regXZ':'act',
    'regYZ':'rep',
    'H':2,
    'Kxz':.1,
    'Kyz':None,  #[.01, .1, .3],
    'Kxy':.1,
    'By':0, 
    'Bz':0, 
    'bt_y': 1, 
    'bt_z': 1, 
    'alp_y': 1, 
    'alp_z': 1,
    'tmin': 0,
    'tmax': 10,
    'N': 1000,
    'start': 1,
    'width': 5,
    'ystart':0,
    'ywidth':0,
    'Q0': [0, 0]
}
fig3d = {
    'header':'Incoherent Type 4 AND($S_Y=0$)',
    'gate':'AND',
    'regXY':'rep', 
    'regXZ':'act',
    'regYZ':'act',
    'H':2,
    'Kxz':.1,
    'Kyz':None,  #[.01, .1, .3],
    'Kxy':.1,
    'By':0, 
    'Bz':0, 
    'bt_y': 1, 
    'bt_z': 1, 
    'alp_y': 1, 
    'alp_z': 1,
    'tmin': 0,
    'tmax': 10,
    'N': 1000,
    'start': 1,
    'width': 5,
    'ystart':0,
    'ywidth':0,
    'Q0': [0, 0]
}

fig3, ax3 = plt.subplots(2, 2, figsize=(8,4), sharex=True, sharey=True)
#figure 3ac
kyz_ac = [.01, .1, .3]
for kyzac in kyz_ac:
    fig3a['Kyz'] = kyzac
    fig3c['Kyz'] = kyzac
    SolveAndPlot(fig3a, ax3[0,0])
    SolveAndPlot(fig3c, ax3[1,0])
#figure 3bd
Kyz_bd = [1, .3, .1]
for kyzbd in Kyz_bd:
    fig3b['Kyz'] = kyzbd
    fig3d['Kyz'] = kyzbd
    SolveAndPlot(fig3b, ax3[0,1])
    SolveAndPlot(fig3d, ax3[1,1])

plt.tight_layout()
# plt.savefig('fig3.png', dpi=450)
plt.show()

# %%
# %run fns.py

fig4a = {
    'header':'Incoherent Type 1 AND($S_Y=1$)',
    'gate':'AND',
    'regXY':'act', 
    'regXZ':'act',
    'regYZ':'rep',
    'H':2,
    'Kxz':1,
    'Kyz':.5,
    'Kxy':.1,
    'By':None, #[.5, .3]
    'Bz':0,  
    'bt_y': 1, 
    'bt_z': 1, 
    'alp_y': 1, 
    'alp_z': 1,
    'tmin': 0,
    'tmax': 10,
    'N': 1000,
    'start': 1,
    'width': 5,
    'ystart':0,
    'ywidth':10,
    'Q0': [1, 0]
}
fig4b = {
    'header':'Incoherent Type 4 AND($S_Y=1$)',
    'gate':'AND',
    'regXY':'rep', 
    'regXZ':'act',
    'regYZ':'act',
    'H': 2,
    'Kxz':1,
    'Kyz':.5,
    'Kxy':.1,#1
    'By':None, #[0.45, 0.35]
    'Bz': 0,  
    'bt_y': 1, 
    'bt_z': 1, 
    'alp_y': 1, 
    'alp_z': 1,
    'tmin': 0,
    'tmax': 10,
    'N': 1000,
    'start': 1,
    'width': 5,
    'ystart':0,
    'ywidth':10,
    'Q0': [1, 0]
}

fig4, ax4 = plt.subplots(1, 2, figsize=(8,4), sharey=True)

by_a =  [.5, .3]
for bya in by_a:
    fig4a['By'] = bya
    SolveAndPlot(fig4a, ax4[0])

by_b = [.45, .35]
for byb in by_b:
    fig4b['By'] = byb 
    SolveAndPlot(fig4b,ax4[1])

plt.tight_layout()
# plt.savefig('fig4.png', dpi=450)
plt.show()

# %%
fig5a = {
    'header':'Coherent Type 1 AND($S_Y=1$)',
    'gate':'AND',
    'regXY':'act', 
    'regXZ':'act',
    'regYZ':'act',
    'H': 2,
    'Kxz':.1,
    'Kyz':None, #[0.5, 5]
    'Kxy':.5,
    'By':0, 
    'Bz': 0, 
    'bt_y': 1, 
    'bt_z': 1, 
    'alp_y': 1, 
    'alp_z': 1,
    'tmin': 0,
    'tmax': 10,
    'N': 1000,
    'start': .1,
    'width': 5,
    'ystart':0,
    'ywidth':10,
    'Q0': [1, 0]
}
fig5b = {
    'header':'Coherent Type 1 AND($S_Y=1$)',
    'gate':'OR',
    'regXY':'act', 
    'regXZ':'act',
    'regYZ':'act',
    'H': 2,
    'Kxz':.1,
    'Kyz':None, #[0.7, 0.3]
    'Kxy':.5,
    'By':0, 
    'Bz': 0,
    'bt_y': 1, 
    'bt_z': 1, 
    'alp_y': 1, 
    'alp_z': 1,
    'tmin': 0,
    'tmax': 10,
    'N': 1000,
    'start': .1,
    'width': 5,
    'ystart':0,
    'ywidth':10,
    'Q0': [1, 0]
}
fig5, ax5 = plt.subplots(1, 2, figsize=(8,4), sharey=True)
Kyz_a = [.5, 5]
for kyza_i in Kyz_a:
    fig5a['Kyz'] = kyza_i
    SolveAndPlot(fig5a, ax5[0])

Kyz_b = [.7, .3]
for kyzb_i in Kyz_b:
    fig5b['Kyz'] = kyzb_i
    SolveAndPlot(fig5b, ax5[1])


plt.tight_layout()
# plt.savefig('fig5.png', dpi=450)
plt.show()
